# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

from rich import print

f = Path.cwd().parents[0]
if str(f) not in sys.path:
    sys.path.insert(0, str(f))
import aoc_input

# %%
from day1 import part1, part2

# %%
sample1 = """1abc2
pqr3stu8vwx
a1b2c3d4e5f
treb7uchet"""

part1(sample1)
# Out:
# 142

# %%
part1(aoc_input.read(2023, 1))
# Out:
# 54605

# %%
sample2 = """two1nine
eightwothree
abcone2threexyz
xtwone3four
4nineeightseven2
zoneight234
7pqrstsixteen"""

part2(sample2)
sum(part2(sample2))
# Out:
# 281

# %%
from day1 import NUM_TEXT_REGEX, convert_num, make_num

for line in sample2.splitlines():
    for m in NUM_TEXT_REGEX.finditer(line):
        print(m)
# Out:
# <re.Match object; span=(0, 3), match='two'>
# <re.Match object; span=(3, 4), match='1'>
# <re.Match object; span=(4, 8), match='nine'>
# <re.Match object; span=(0, 5), match='eight'>
# <re.Match object; span=(7, 12), match='three'>
# <re.Match object; span=(3, 6), match='one'>
# <re.Match object; span=(6, 7), match='2'>
# <re.Match object; span=(7, 12), match='three'>
# <re.Match object; span=(1, 4), match='two'>
# <re.Match object; span=(6, 7), match='3'>
# <re.Match object; span=(7, 11), match='four'>
# <re.Match object; span=(0, 1), match='4'>
# <re.Match object; span=(1, 5), match='nine'>
# <re.Match object; span=(5, 10), match='eight'>
# <re.Match object; span=(10, 15), match='seven'>
# <re.Match object; span=(15, 16), match='2'>
# <re.Match object; span=(1, 4), match='one'>
# <re.Match object; span=(8, 9), match='2'>
# <re.Match object; span=(9, 10), match='3'>
# <re.Match object; span=(10, 11), match='4'>
# <re.Match object; span=(0, 1), match='7'>
# ...

# %%
nums = [
    [convert_num(m.group()) for m in NUM_TEXT_REGEX.finditer(line)]
    for line in sample2.splitlines()
]
print('\n'.join(map(str, nums)))
nums = [make_num(digits) for digits in nums]
print('\n'.join(map(str, nums)))
print(sum(nums))
# Out:
# [2, 1, 9]
# [8, 3]
# [1, 2, 3]
# [2, 3, 4]
# [4, 9, 8, 7, 2]
# [1, 2, 3, 4]
# [7, 6]
# 29
# 83
# 13
# 24
# 42
# 14
# 76
# 281

# %%
part2(aoc_input.read(2023, 1))
# Out:
# [23,
#  27,
#  94,
#  41,
#  71,
#  16,
#  77,
#  65,
#  22,
#  95,
#  41,
#  47,
#  32,
#  98,
#  19,
#  22,
#  19,
#  41,
#  72,
#  33,
#  62,
#  91,
#  46,
#  86,
#  89,
#  21,
#  83,
#  12,
#  58,
#  75,
#  88,
#  76,
#  99,
#  59,
#  11,
#  67,
#  72,
#  29,
#  52,
#  63,
#  66,
#  11,
#  55,
#  53,
#  65,
#  48,
#  44,
#  31,
#  35,
#  26,
#  71,
#  62,
#  44,
#  93,
#  58,
#  91,
#  85,
#  32,
#  81,
#  14,
#  79,
#  34,
#  61,
#  44,
#  54,
#  58,
#  87,
#  93,
#  99,
#  24,
#  18,
#  79,
#  64,
#  69,
#  83,
#  28,
#  96,
#  94,
#  69,
#  87,
#  81,
#  32,
#  38,
#  27,
#  17,
#  29,
#  23,
#  56,
#  96,
#  24,
#  11,
#  78,
#  18,
#  82,
#  86,
#  57,
#  54,
#  79,
#  83,
#  92,
#  53,
#  25,
#  84,
#  69,
#  98,
#  11,
#  45,
#  49,
#  82,
#  29,
#  54,
#  53,
#  69,
#  24,
#  55,
#  22,
#  62,
#  44,
#  36,
#  74,
#  61,
#  45,
#  87,
#  38,
#  38,
#  54,
#  88,
#  65,
#  35,
#  99,
#  12,
#  88,
#  95,
#  11,
#  21,
#  11,
#  68,
#  52,
#  69,
#  69,
#  82,
#  41,
# ...
